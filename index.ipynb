# %% [markdown]
# # One-Sample z-test - Lab
#
# ## Introduction
# In this lab you'll perform a few quick tests to help you better understand how hypothesis testing works.
#
# ## Objectives
# You will be able to:
# * Understand and explain use cases for a one-sample z-test
# * Set up null and alternative hypotheses
# * Calculate z-statistic using z-tables and CDF functions
# * Calculate and interpret p-value for significance of results
#
# ## Exercise 1
# A fast food chain claims that the mean time to order food at their restaurants is 60 seconds, with a standard deviation of 30 seconds. You decide to put this claim to the test and go to one of the restaurants to observe actual waiting times. You take a sample of 36 customers and find that the mean order time was 75 seconds. Does this finding prove enough evidence to contradict the fast food chain's claim of fast service?
#
# Follow the 5 steps shown in previous lesson and use $\alpha$ = 0.05.

# %%
# State your null and alternative hypotheses
# Null hypothesis is that this is sample is within normal variance H0 : mu <= M
# Alternative hypothesis is that this sample is significantly higher than the claim: mu < M

# %%
# Your solution here
import scipy.stats as stats
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
plt.style.use('dark_background')

x_bar = 75
n = 36
sigma = 30
mu = 60

z = (x_bar-mu)/(sigma/np.sqrt(n))
print(f"z-statistic: {z}")
pval = 1 - stats.norm.cdf(z)
print(f"p-value: {pval}")

plt.fill_between(x=np.arange(-4,z, 0.01),
                y1 = stats.norm.pdf(np.arange(-4,z,0.01)),
                facecolor = 'red',
                alpha = 0.35,
                label = 'Area below z-statistic')
plt.fill_between(x=np.arange(z,4,0.01),
                y1 = stats.norm.pdf(np.arange(z,4,0.01)),
                facecolor='blue',
                alpha = 0.35,
                label= 'Area above z-statistic')
plt.legend()
plt.title('Customer wait times z-distribution')
plt.show()

# (p = 0.0013498980316301035, z = 3.0)
# Out:
# z-statistic: 3.0
# p-value: 0.0013498980316301035

# %%
# Interpret the results in terms of the p-value
# The p-value is less than the alpha of 0.05, meaning that we can reject the null hypothesis
# and say that the evidence of the study strongly suggests that the wait times at the restaurant
# are significanlty longer than advertised.

# %% [markdown]
# ## Exercise 2
#
# 25 students complete a preparation program for taking the SAT test.  Here are the SAT scores from the 25 students who completed  program:
#
# ``
# 434 694 457 534 720 400 484 478 610 641 425 636 454
# 514 563 370 499 640 501 625 612 471 598 509 531
# ``
#
# We know that the population average for SAT scores is 500 with a standard deviation of 100.
#
# Are our 25 students’ SAT scores significantly higher than the population's mean score?
#
# *Note that the SAT preparation program claims that it will increase (and not decrease) the SAT score.  So, you can conduct a one-directional test. (alpha = .05).*

# %%
# State your hypotheses 
# The null hypothesis is the prep program had no effect on the scores. (Ha: mu >= M)
# The alternative hypothesis is that the scores are significantly higher. (H0: mu < M)

# %%
# Give your solution here 
scores = [434, 694, 457, 534, 720, 400, 484, 478, 610, 641, 425, 636, 454,
         514, 563, 370, 499, 640, 501, 625, 612, 471, 598, 509, 531]
scores_arr = np.array(scores)

x_bar = scores_arr.mean()
n = 25
sigma = 100
mu = 500

z = (x_bar-mu)/(sigma/np.sqrt(n))
print(f"z-statistic: {z}")
pval = 1 - stats.norm.cdf(z)
print(f"p-value: {pval}")

plt.fill_between(x=np.arange(-4,z, 0.01),
                y1 = stats.norm.pdf(np.arange(-4,z,0.01)),
                facecolor = 'red',
                alpha = 0.35,
                label = 'Area below z-statistic')
plt.fill_between(x=np.arange(z,4,0.01),
                y1 = stats.norm.pdf(np.arange(z,4,0.01)),
                facecolor='blue',
                alpha = 0.35,
                label= 'Area above z-statistic')
plt.legend()
plt.title('Customer wait times z-distribution')
plt.show()
# p = 0.03593031911292577, z = 1.8
# Out:
# z-statistic: 1.8
# p-value: 0.03593031911292577

# %%
# Interpret the results in terms of the p-value
# The p-value is 0.036, lower than the alpha of 0.05, meaning we can reject the null hypothesis
# and say that study strongly suggests the prep course did raise the student's scores 
# significantly

# %% [markdown]
# ## Summary
#
# In this lesson, you conducted a couple of simple tests comparing sample and population means, in an attempt to reject our null hypotheses. This provides you with a strong foundation to move ahead with more advanced tests and approaches later on.
